# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Hassaan7645/Internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*
#
# **Answer**: One row is equal to one content item. In this case one page (web page).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*
#
# **Answer**: Following are the fields:
#
# **1. Feature**: word_count, search_volume, competition, competition_level, cpc, content_type, main_intent, content_age_days, days_since_last_update
#
# **2. Label**: impressions_90d, clicks_90d, pageviews_90d, scroll_events_90d, ctr, scroll_rate
#
# **3. Context**: content_id, client_id
#
# **4. Excluded**: provider_used, model_used
#
# Reason: Which LLM used has nothing to do with wether length drives engagement.
#
# Also char_count is redundant with word_count.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*
#
# **Answer**: Output claim by claim
#
# **Grain**: 30,000 rows, 30,000 unique content_id, 0 duplicates.
#
# **Counts**: word_count present on 22,301 rows, missing on 7,699. impressions_90d is never below 1 — the dictionary's "every row ≥ 1" claim holds with zero exceptions.
#
# **Missing Values**: The real finding here is that word_count isn't missing randomly, and it's not spread how you'd guess. It's 100% concentrated in one content_type.
#
# **Windows**: content_age_days min = 90, confirmed. Window nesting: 0 violations across all 30,000 rows, median gap (days 61–90) = 308 which is consistent with section 1.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*
#
# **Answer**: Following are some things data never shows:
#
# 1. It does not show any content younger than 90 days.
# 2. There is no client control. 32 clients, never checked whether the word-count/engagement relationship holds within a client or is really "some clients happen to write medium-length content and also happen to run higher-engagement sites".
# 3. Correlational, not causal. Word count wasn't randomly assigned. Whatever drove a page to be long or short (topic, brief requirements, writer habits) is entangled with the outcome. "Medium beats long" describes an association, not a mechanism.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Hassaan7645/Internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# **Answer**: My lane as an ML task it ranking (Lane 1). My question will prove wether the statement "longer pages engage better" is true or not.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# **Answer**: My prediction will matter according to the data provided to me. After checking multiple entries in the data I will be able to predict the result of my model. This label comes from observed outcome not a defined rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# **Answer**: The success metric will be according to the search_volume or the engagement rate. More the search volume of a specific page will tell us wether the statement "longer text engage better" is true or not.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# content_id / content_type / word_count / word_count_tier /   engagement_rate / scroll_rate
#
# content_304f48230142 / keyword article / 3221.0 / 2000-3500 / 5.88 / 4.55
#
# content_a1fb4e703a9e / keyword article / 2481.0 / 2000-3500 / 0.00 / 10.00
#
# content_9aa793d4d895 / keyword article / 3515.0 / 3500+ / 0.00 / 28.57
#
# content_331d6c4de07b / keyword article / NaN / NaN / 1.28 / 3.45
#
# content_d99b7a2d90ca / keyword article / 2803.0 / 2000-3500 / 0.00 / 24.29
#
# The main unit of analysis is the word_count and the engagement rate.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# **Answer**: Some of the pages engage better because of the quality of the content present in them while others engage better because of the lenghty content. So, there is not a specific pattern we can follow here in order to decide wether the webpage is engaging or not. If we use many if-statements here, the pattern will become too messy to follow through.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

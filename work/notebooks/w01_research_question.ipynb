# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Hassaan7645/Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
#
# **Lane 1**:
#
# **Question**: Is there an actual relationship between word_cout and engagement_rate / scroll_rate, or is "longer pages engage better" just an assumption?
#
# **Reason**: I chose this option because this is the cleanest test in lane one that has a direct correlation. It also tests common strategy assumption i.e., "longer pages engage better" against actual data. Even if the correlation comes out to be weak, that still is a usefull data.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
#
#
# **Decision**: It improves the decision wether to expand thin pages as a strategy.
#
# **Actions**: The content strategist deciding expansion backlog.
#
# **Cost**: Bloating pages with no engagement payoff.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# **Answer**:
# On the full starter dataset, word_count barely correlates with engagement_rate and only weakly with scroll_rate. But split into tiers, a real pattern shows up:
#
#
# 1. Pages under 1,000 words scroll at 48.4% which is more than double every other tier
# 2. Pages over 3,500 words have the worst engagement of any bucket.
#
# The gap mentioned above is worth the investigation for the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# **Answer**: My work will be able to prove wether the fact "longer pages engage better" is true or false. It will not be able to tell the quality of the content present on the page.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
